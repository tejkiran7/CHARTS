# %%
import seaborn as sns
import pandas as pd

import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\TEJKIRAN\Desktop\sales.csv",engine ='python')
df.head()
# Out:
#    Row ID  Order ID  Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3  13-10-2010            Low               6    261.5400
# 1      49       293  01-10-2012           High              49  10123.0200
# 2      50       293  01-10-2012           High              27    244.5700
# 3      80       483  10-07-2011           High              30   4965.7595
# 4      85       515  28-08-2010  Not Specified              19    394.2700
#
#    Discount       Ship Mode   Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.25       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck   457.81      208.16  ...        Barry French
# 2      0.01     Regular Air    46.71        8.69  ...        Barry French
# 3      0.08     Regular Air  1198.97      195.99  ...       Clay Rozendal
# 4      0.08     Regular Air    30.94       21.78  ...      Carlos Soltero
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
sns.relplot('Order Date',"Sales",data=df,kind="line")

# %%
df['Order Date']=pd.to_datetime(df['Order Date'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6246 entries, 0 to 6245
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                6246 non-null   int64
#  1   Order ID              6246 non-null   int64
#  2   Order Date            6246 non-null   datetime64[ns]
#  3   Order Priority        6246 non-null   object
#  4   Order Quantity        6246 non-null   int64
#  5   Sales                 6246 non-null   float64
#  6   Discount              6246 non-null   float64
#  7   Ship Mode             6246 non-null   object
#  8   Profit                6246 non-null   float64
#  9   Unit Price            6246 non-null   float64
#  10  Shipping Cost         6246 non-null   float64
#  11  Customer Name         6246 non-null   object
#  12  Province              6246 non-null   object
#  13  Region                6246 non-null   object
# ...

# %%
df['year'] = df['Order Date'].dt.year

# %%
df.year.unique()
# Out:
# array([2010, 2012, 2011], dtype=int64)

# %%
sns.relplot('year','Sales',data=df,kind='line')

# %%
sns.relplot('year','Sales',data=df,kind='line',ci=None)

# %%
sns.relplot('year','Sales',data=df,kind='line',ci="sd")

# %%
sns.relplot('year','Sales',data=df,kind='line',estimator=None)

# %%
sns.relplot('year','Sales',data=df,kind='line',estimator=sum)

# %%
sns.relplot('year','Sales',data=df,kind='line',hue="Ship Mode")

# %%
sns.relplot('year','Sales',data=df,kind='line',style="Product Category")

# %%
sns.relplot('year','Sales',data=df,kind='line',style="Product Category",ci=None) #ci=Confidence Interval

# %%
sns.relplot('year','Sales',data=df,kind='line',col="Product Category",ci=None) #ci=Confidence Interval

# %%
sns.relplot('year','Sales',data=df,kind='line',col="Region",ci=None) #ci=Confidence Interval

# %%
sns.relplot('year','Sales',data=df,kind='line',col="Region",ci=None,col_wrap=4) #ci=Confidence Interval

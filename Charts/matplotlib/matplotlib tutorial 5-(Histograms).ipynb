# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
blood_sugar=[115,85,90,150,149,88,93,115,135,80,77,82,129]
#plt.hist(blood_sugar,bins=3,rwidth=0.95)
plt.hist(blood_sugar,bins=[80,100,125,150],rwidth=0.95,color="g",histtype="step")
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  [<matplotlib.patches.Polygon at 0x16a07bf7288>])

# %%
blood_sugar_men=[115,85,90,150,149,88,93,115,135,80,77,82,129]
blood_sugar_women=[67,98,89,120,133,150,84,69,89,79,120,112,100]
plt.xlabel("sugar range")
plt.ylabel("Total no of patient")
plt.title("Blood sugar analysis")
plt.hist([blood_sugar_men,blood_sugar_women],bins=[80,100,125,150],rwidth=0.95,color=["green","orange"],label=['men','women'],orientation="horizontal")
plt.legend()
